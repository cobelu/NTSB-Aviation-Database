# %% [markdown]
# # Examples

# %%
import pandas as pd

# %%
pd.read_csv('../data/Country.csv').head()
# Out:
#   COUNTRY_CODE   COUNTRY_NAME
# 0           LI        Liberia
# 1           LO       Slovakia
# 2           LS  Liechtenstein
# 3           LT        Lesotho
# 4           LU     Luxembourg

# %%
pd.read_csv('../data/Events_Sequence.csv').head()
# Out:
#             ev_id  Aircraft_Key  Occurrence_No  Occurrence_Code  \
# 0  20181125X85246             1              1           551090
# 1  20181125X85246             1              2           551230
# 2  20181125X85246             1              3           551094
# 3  20181125X85246             1              4           551096
# 4  20120214X84853             1              1           551092
#
#                               Occurrence_Description  phase_no  eventsoe_no  \
# 0  Landing-flare/touchdown - Abnormal runway contact       551           90
# 1  Landing-flare/touchdown - Loss of control on g...       551          230
# 2    Landing-flare/touchdown - Landing gear collapse       551           94
# 3      Landing-flare/touchdown - Nose over/nose down       551           96
# 4             Landing-flare/touchdown - Hard landing       551           92
#
#    Defining_ev          lchg_date lchg_userid
# 0            0  07/08/19 18:40:13        seak
# ...

# %%
pd.read_csv('../data/Findings.csv').head()
# Out:
#             ev_id  Aircraft_Key  finding_no  finding_code  category_no  \
# 0  20181125X85246             1           1     106202220            1
# 1  20181125X85246             1           2     206304044            2
# 2  20120214X84853             1           1     106203711            1
# 3  20120214X84853             1           2     204101544            2
# 4  20170103X43747             1           1     500000000            5
#
#    subcategory_no  section_no  \
# 0               6          20
# 1               6          30
# 2               6          20
# 3               4          10
# 4               0           0
#
#                                  finding_description  subsection_no  \
# 0  Aircraft-Aircraft oper/perf/capability-Perform...             22
# 1  Personnel issues-Task performance-Use of equip...             40
# 2  Aircraft-Aircraft oper/perf/capability-Perform...             37
# 3  Personnel issues-Action/decision-Action-Incorr...             15
# ...

# %%
pd.read_csv('../data/Flight_Crew.csv').head()
# Out:
#             ev_id  Aircraft_Key  crew_no crew_category  crew_age crew_sex  \
# 0  20001208X07734             1        1         PLT        55.0        M
# 1  20080718X01072             1        1         PLT        68.0        M
# 2  20110716X12058             1        1         PLT        75.0        M
# 3  20020917X03633             1        1         PLT        32.0        M
# 4  20120214X84853             1        1         PLT        35.0        M
#
#          crew_city crew_res_state crew_res_country med_certf  ...  \
# 0  LAS VEGAS                   NV              NaN      CL2   ...
# 1          Bozeman             MT             USA       CL3   ...
# 2  Marshalls Creek             PA             USA       CL3   ...
# 3                                              NaN      CL2   ...
# 4          Marsing             ID             USA       CL2   ...
#
#           lchg_userid seat_occ_row infl_rest_inst infl_rest_depl  \
# ...

# %%
pd.read_csv('../data/NTSB_Admin.csv').head()
# Out:
#             ev_id rec_stat      approval_date         lchg_userid  \
# 0  20001208X07734        B  02/11/00 00:00:00  NTSB_eADMS
# 1  20021008X05297        B  04/23/03 00:00:00  NTSB_eADMS
# 2  20040127X00111        B  04/28/05 00:00:00  NTSB_eADMS
# 3  20181125X85246        B  09/26/19 00:00:00  hopj
# 4  20001213X34369        B                NaN  NTSB_eADMS
#
#            lchg_date
# 0  09/30/08 13:06:01
# 1  09/30/08 13:06:01
# 2  09/30/08 13:06:01
# 3  09/26/19 14:05:15
# 4  09/30/08 13:06:01

# %%
pd.read_csv('../data/Occurrences.csv').head()
# Out:
#             ev_id  Aircraft_Key  Occurrence_No  Occurrence_Code  \
# 0  20001208X07734             1              1              130
# 1  20001208X07734             1              2              250
# 2  20001208X07734             1              3              130
# 3  20001208X07734             1              4              230
# 4  20021008X05297             1              1              353
#
#    Phase_of_Flight  Altitude          lchg_date         lchg_userid
# 0              540         0  12/08/00 12:15:21  dbo
# 1              540         0  12/08/00 12:15:21  dbo
# 2              553         0  12/08/00 12:15:21  dbo
# 3              553         0  12/08/00 12:15:21  dbo
# 4              564         0  04/18/03 13:26:35  JOHB

# %%
pd.read_csv('../data/aircraft.csv').head()
# Out:
#             ev_id  Aircraft_Key regis_no      ntsb_no acft_missing far_part  \
# 0  20001208X07734             1   N6172C  LAX97FA143             N     091
# 1  20021008X05297             1   N9714W   CHI02LA299          NaN     091
# 2  20040127X00111             1   N7127V   LAX04LA103          NaN     091
# 3  20181125X85246             1   N66710   GAA19CA073          NaN     091
# 4  20001213X34369             1   N70021  ANC86LA135             N     091
#
#   flt_plan_filed flight_plan_activated damage acft_fire  ... acft_year  \
# 0           IFR                    NaN   DEST      NONE  ...       NaN
# 1           NONE                     N   SUBS      NONE  ...       NaN
# 2           VFR                      Y   SUBS      NONE  ...       NaN
# 3           NONE                     U   SUBS      NONE  ...    1983.0
# 4           NONE                   NaN   SUBS      NONE  ...       NaN
#
#   fuel_on_board commercial_space_flight unmanned ifr_equipped_cert  \
# ...

# %%
pd.read_csv('../data/ct_iaids.csv').head()
# Out:
#             ct_name code_iaids              meaning   seq ntsb_type ntsb_code  \
# 0               NaN       FOIA                 FOIA   4.0       NaN       NaN
# 1  ct_acft_awy_cert       LTSP  Special Light-Sport  12.0         N        12
# 2  ct_acft_awy_cert        OTH                Other  40.0         N       NaN
# 3  ct_acft_awy_cert        SPE         Experimental  11.0         N        11
# 4  ct_acft_awy_cert        SPL              Limited   8.0         N        08
#
#   avn_code ntsb_codes_more  not_for_ntsb_use  eADMS_use             notes
# 0      NaN             NaN                 0          1  Special Handling
# 1      NaN             NaN                 0          1               NaN
# 2      NaN             NaN                 0          1               NaN
# 3      NaN             NaN                 0          1               NaN
# 4      NaN             NaN                 0          1               NaN

# %%
pd.read_csv('../data/ct_seqevt.csv').head()
# Out:
#    code                                        meaning
# 0   100                                ABRUPT MANEUVER
# 1   110                ALTITUDE DEVIATION,UNCONTROLLED
# 2   120                                    CARGO SHIFT
# 3   130  AIRFRAME/COMPONENT/SYSTEM FAILURE/MALFUNCTION
# 4   131                  PROPELLER FAILURE/MALFUNCTION

# %%
pd.read_csv('../data/dt_Flight_Crew.csv').head()
# Out:
#             ev_id  Aircraft_Key  crew_no           col_name  code  \
# 0  20001208X07734             1        1     crew_cert_code  PRI
# 1  20001208X07734             1        1    crew_rat_airpln  SEL
# 2  20001208X07734             1        1  crew_rat_instruct  NONE
# 3  20001208X07734             1        1   crew_rat_instrum  APLN
# 4  20001208X07734             1        1      crew_rat_roto  NONE
#
#            lchg_date         lchg_userid
# 0  12/08/00 12:13:19  dbo
# 1  12/08/00 12:13:19  dbo
# 2  12/08/00 12:13:19  dbo
# 3  12/08/00 12:13:19  dbo
# 4  12/08/00 12:13:19  dbo

# %%
pd.read_csv('../data/dt_aircraft.csv').head()
# Out:
#             ev_id  Aircraft_Key       col_name  code          lchg_date  \
# 0  20001208X07734             1  acft_awy_cert  STN   12/08/00 12:13:19
# 1  20001208X07734             1    airspc_type  CLE   12/08/00 12:13:19
# 2  20001208X07734             1     instm_appr  NONE  12/08/00 12:13:19
# 3  20001208X07734             1   landing_gear  TRI   12/08/00 12:13:19
# 4  20001208X07734             1      load_desc  PAX   12/08/00 12:13:19
#
#           lchg_userid
# 0  dbo
# 1  dbo
# 2  dbo
# 3  dbo
# 4  dbo

# %%
pd.read_csv('../data/dt_events.csv').head()
# Out:
#             ev_id              col_name  code          lchg_date  \
# 0  20001208X07734  prop_dmg              TREE  12/08/00 12:13:19
# 1  20001208X07734  vis_restrct           NONE  12/08/00 12:13:19
# 2  20001208X07734  wx_brief_mthd         TELE  12/08/00 12:13:19
# 3  20001208X07734  wx_brief_src          FSS   12/08/00 12:13:19
# 4  20001208X07734  wx_cond               S     12/08/00 12:13:19
#
#           lchg_userid
# 0  dbo
# 1  dbo
# 2  dbo
# 3  dbo
# 4  dbo

# %%
pd.read_csv('../data/eADMSPUB_DataDictionary.csv').head()
# Out:
#   Category of Data     Table         Column      ct_name code_iaids  \
# 0       eADMS Data  aircraft  acft_category  ct_acft_cat        AIR
# 1       eADMS Data  aircraft  acft_category  ct_acft_cat       BALL
# 2       eADMS Data  aircraft  acft_category  ct_acft_cat       BLIM
# 3       eADMS Data  aircraft  acft_category  ct_acft_cat        GLI
# 4       eADMS Data  aircraft  acft_category  ct_acft_cat       GYRO
#
#      meaning Data Type eADMS  Length eADMS         short_desc  \
# 0   Airplane            char           4.0  Aircraft Category
# 1    Balloon            char           4.0  Aircraft Category
# 2      Blimp            char           4.0  Aircraft Category
# 3     Glider            char           4.0  Aircraft Category
# 4  Gyrocraft            char           4.0  Aircraft Category
#
#                                         Question_Def Code meaning  \
# 0  The category of the involved aircraft. In this...          NaN
# ...

# %%
pd.read_csv('../data/engines.csv').head()
# Out:
#             ev_id  Aircraft_Key  eng_no eng_type       eng_mfgr  \
# 0  20001208X07734             1       1     REC   Continental
# 1  20040127X00111             1       1     REC        Lycoming
# 2  20181125X85246             1       1     REC        Lycoming
# 3  20001213X34369             1       1     REC   CONTINENTAL
# 4  20001213X35290             1       1     REC   CONTINENTAL
#
#        eng_model  power_units hp_or_lbs lchg_userid          lchg_date  \
# 0  TSIO-520-R           310.0      HP           NaN  12/08/00 12:12:52
# 1     IO-360-A1A        200.0      HP           NaN                NaN
# 2      O-360-A4K        180.0      HP           NaN  12/19/18 16:32:34
# 3  IO-520               300.0      HP           NaN  12/13/00 16:42:19
# 4  C-90-12F              90.0      HP           NaN  12/13/00 17:29:21
#
#   carb_fuel_injection propeller_type  propeller_make  propeller_model  \
# 0                FINJ            NaN             NaN              NaN
# ...

# %%
pd.read_csv('../data/events.csv').head()
# Out:
#             ev_id     ntsb_no ev_type            ev_date ev_dow  ev_time  \
# 0  20001208X07734  LAX97FA143     ACC  04/02/97 00:00:00     WE   2016.0
# 1  20021008X05297  CHI02LA299     ACC  09/29/02 00:00:00     Su   2100.0
# 2  20040127X00111  LAX04LA103     ACC  10/12/03 00:00:00     Su   1640.0
# 3  20181125X85246  GAA19CA073     ACC  11/25/18 00:00:00     Su   1320.0
# 4  20001213X34369  ANC86LA135     ACC  08/23/86 00:00:00     SA   1100.0
#
#   ev_tmzn          ev_city ev_state ev_country  ... invest_agy  ntsb_docket  \
# 0     MST  GRAND CANYON          AZ        USA  ...          N       1890.0
# 1     CDT         Moorhead       MN        USA  ...          N      13246.0
# 2     MST       Scottsdale       AZ        USA  ...          N      17586.0
# 3     PST      Porterville       CA        USA  ...          N      38685.0
# 4     AKD  TALKEETNA             AK        USA  ...          N        891.0
#
#                    ntsb_notf_from     ntsb_notf_date ntsb_notf_tm  \
# ...

# %%
pd.read_csv('../data/flight_time.csv').head()
# Out:
#             ev_id  Aircraft_Key  crew_no flight_type flight_craft  \
# 0  20001208X07734             1        1        L24H         ACTU
# 1  20001208X07734             1        1        L24H         ALL
# 2  20001208X07734             1        1        L24H         MAKE
# 3  20001208X07734             1        1        L24H         NGHT
# 4  20001208X07734             1        1        L24H         SENG
#
#    flight_hours          lchg_date         lchg_userid
# 0           1.0  12/08/00 12:13:19  dbo
# 1           3.0  12/08/00 12:13:19  dbo
# 2           3.0  12/08/00 12:13:19  dbo
# 3           2.0  12/08/00 12:13:19  dbo
# 4           3.0  12/08/00 12:13:19  dbo

# %%
pd.read_csv('../data/injury.csv').head()
# Out:
#             ev_id  Aircraft_Key inj_person_category injury_level  \
# 0  20001208X07734             1                ABRD         FATL
# 1  20001208X07734             1                ABRD         TOTL
# 2  20001208X07734             1                PAX          FATL
# 3  20001208X07734             1                PAX          TOTL
# 4  20001208X07734             1                PLT          FATL
#
#    inj_person_count          lchg_date         lchg_userid
# 0               2.0  12/08/00 12:13:19  dbo
# 1               2.0  12/08/00 12:13:19  dbo
# 2               1.0  12/08/00 12:13:19  dbo
# 3               1.0  12/08/00 12:13:19  dbo
# 4               1.0  12/08/00 12:13:19  dbo

# %%
pd.read_csv('../data/seq_of_events.csv').head()
# Out:
#             ev_id  Aircraft_Key  Occurrence_No  seq_event_no  group_code  \
# 0  20001208X07734             1              1             1           1
# 1  20001208X07734             1              1             2           1
# 2  20001208X07734             1              1             3           1
# 3  20001208X07734             1              2             1           2
# 4  20001208X07734             1              2             2           3
#
#    Subj_Code Cause_Factor  Modifier_Code  Person_Code          lchg_date  \
# 0      12005            C           1150          0.0  12/08/00 12:15:21
# 1      17202                        1150          0.0  12/08/00 12:15:21
# 2      13102                        1150          0.0  12/08/00 12:15:21
# 3      24566            C           3127       4000.0  12/08/00 12:15:21
# 4      33400            F              0       4000.0  07/19/01 10:05:41
#
#           lchg_userid
# 0  dbo
# 1  dbo
# 2  dbo
# 3  dbo
# 4  dbo

# %%
pd.read_csv('../data/states.csv').head()
# Out:
#   state                            name faa_region
# 0    AK  ALASKA                                 AL
# 1    AL  ALABAMA                                SO
# 2    AR  ARKANSAS                               SW
# 3    AZ  ARIZONA                                WP
# 4    CA  CALIFORNIA                             WP
